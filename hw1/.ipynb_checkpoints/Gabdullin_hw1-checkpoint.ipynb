# %% [markdown]
# **Общая информация**
#
# **Срок сдачи:** 16 марта 2020, 08:30
#
# **Штраф за опоздание:** по 1 баллу за 24 часа задержки. Через 5 дней домашнее задание сгорает.
#
# При отправлении ДЗ указывайте фамилию в названии файла
# Присылать ДЗ необходимо в виде ссылки на свой github репозиторий на почту ml1.sphere@mail.ru с указанием темы в следующем формате:
#
# [ML0220, Задание 1] Фамилия Имя.
#
# Используйте данный Ipython Notebook при оформлении домашнего задания.

# %% [markdown]
# **Штрафные баллы:**
#
# 1. Отсутствие фамилии в имени скрипта (скрипт должен называться по аналогии со stroykova_hw1.ipynb) -0.5 баллов
# 2. Все строчки должны быть выполнены. Нужно, чтобы output команды можно было увидеть уже в git'е. В противном случае -0.5 баллов

# %%
import numpy as np
import scipy
from scipy.spatial.distance import pdist, squareform, cdist
import matplotlib.pyplot as plt

import seaborn as sns
from sklearn import datasets
from sklearn.base import BaseEstimator
from sklearn.datasets import fetch_openml, fetch_20newsgroups

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier, KDTree
from sklearn.metrics import accuracy_score, pairwise_distances
import sklearn

# %% [markdown]
# ##### Задание 1 (1 балл)
# Реализовать KNN в классе MyKNeighborsClassifier (обязательное условие: точность не ниже sklearn реализации)
# Разберитесь самостоятельно, какая мера расстояния используется в KNeighborsClassifier дефолтно и реализуйте свой алгоритм именно с этой мерой.
# Для подсчета расстояний можно использовать функции [отсюда](https://docs.scipy.org/doc/scipy/reference/spatial.distance.html)

# %%
class MyKNeighborsClassifier(BaseEstimator):    
    dataset = np.array([])
    answers = np.array([])
    algorithm = ''
    metric = ''
    k = 1
    
    def __init__(self, n_neighbors, algorithm='brute', metric='euclidean'):
        self.metric = metric
        self.k = n_neighbors
        self.algorithm = algorithm
        pass
    
    def fit(self, X, y):
        self.dataset = X
        self.answers = y
        pass
    
    def brute(self, x):
        
        if type(x) == scipy.sparse.csr.csr_matrix:
            
            dist = pairwise_distances(x, self.dataset, metric=self.metric)
            
            indices = np.argpartition(dist, self.k, axis=1)[:, :self.k]
            
            return np.apply_along_axis(np.bincount, 1, self.answers[indices], minlength=self.k).argmax(axis=1)
        
        
        dist = cdist(x[np.newaxis], self.dataset, metric=self.metric)[0]
        indices = np.argpartition(dist, self.k + 1, 0)[:self.k]
        answers = self.answers[indices]
        prediction = np.argmax(np.bincount(answers, minlength=self.k))
        return prediction
        
    def kd_tree(self, x):
        tree = KDTree(self.dataset)
        indices = tree.query(x[np.newaxis], self.k, return_distance=False)
        answers = self.answers[indices.ravel()]
        prediction = np.argmax(np.bincount(answers, minlength=self.k))
        return prediction
    
    def predict_proba(self, x):
        
        if self.algorithm == 'kd_tree':
            return self.kd_tree(x)
        
        return self.brute(x)
    
    def predict(self, X):
        if self.algorithm == 'kd_tree':
            return np.apply_along_axis(self.predict_proba, 1, X)
        elif self.algorithm == 'brute':
            if type(X) == scipy.sparse.csr.csr_matrix:
                return self.brute(X)
            return np.apply_along_axis(self.predict_proba, 1, X)
    def score(self, X, y):
        return accuracy_score(y, self.predict(X))

# %% [markdown]
# **IRIS**
#
# В библиотеке scikit-learn есть несколько датасетов из коробки. Один из них [Ирисы Фишера](https://ru.wikipedia.org/wiki/%D0%98%D1%80%D0%B8%D1%81%D1%8B_%D0%A4%D0%B8%D1%88%D0%B5%D1%80%D0%B0)

# %%
iris = datasets.load_iris()

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.1, stratify=iris.target)

# %%
clf = KNeighborsClassifier(n_neighbors=2, algorithm='brute')
my_clf = MyKNeighborsClassifier(n_neighbors=2, algorithm='brute')

# %%
clf.fit(X_train, y_train)
my_clf.fit(X_train, y_train)

# %%
sklearn_pred = clf.predict(X_test)
my_clf_pred = my_clf.predict(X_test)
assert abs( accuracy_score(y_test, my_clf_pred) -  accuracy_score(y_test, sklearn_pred ) )<0.005, "Score must be simillar"

# %%
sklearn_pred, my_clf_pred
# Out:
# (array([0, 0, 1, 1, 0, 1, 2, 1, 2, 1, 1, 1, 2, 0, 0]),
#  array([0, 0, 1, 1, 0, 1, 2, 1, 2, 1, 1, 1, 2, 0, 0], dtype=int64))

# %% [markdown]
# **Задание 2 (0.5 балла)**
#
# Давайте попробуем добиться скорости работы на fit, predict сравнимой со sklearn для iris. Допускается замедление не более чем в 2 раза.
# Для этого используем numpy.

# %%
# %time clf.fit(X_train, y_train)
# Out:
# Wall time: 999 µs
# KNeighborsClassifier(algorithm='brute', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                      weights='uniform')

# %%
# %time my_clf.fit(X_train, y_train)
# Out:
# Wall time: 0 ns

# %%
# %time clf.predict(X_test)
# Out:
# Wall time: 2 ms
# array([0, 0, 1, 1, 0, 1, 2, 1, 2, 1, 1, 1, 2, 0, 0])

# %%
# %time my_clf.predict(X_test)
# Out:
# Wall time: 3.99 ms
# array([0, 0, 1, 1, 0, 1, 2, 1, 2, 1, 1, 1, 2, 0, 0], dtype=int64)

# %% [markdown]
# ###### Задание 3 (1 балл)
# Добавьте algorithm='kd_tree' в реализацию KNN (использовать KDTree из sklearn.neighbors). Необходимо добиться скорости работы на fit,  predict сравнимой со sklearn для iris. Допускается замедление не более чем в 2 раза.
# Для этого используем numpy. Точность не должна уступать значению KNN из sklearn.

# %%
clf = KNeighborsClassifier(n_neighbors=2, algorithm='kd_tree')
my_clf = MyKNeighborsClassifier(n_neighbors=2, algorithm='kd_tree')

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.1, stratify=iris.target)

# %%
# %time clf.fit(X_train, y_train)
# Out:
# Wall time: 997 µs
# KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                      weights='uniform')

# %%
# %time my_clf.fit(X_train, y_train)
# Out:
# Wall time: 0 ns

# %%
# %time clf.predict(X_test)
# Out:
# Wall time: 2.99 ms
# array([0, 2, 2, 1, 0, 1, 2, 1, 0, 2, 2, 1, 2, 0, 0])

# %%
# %time my_clf.predict(X_test)
# Out:
# Wall time: 3.99 ms
# array([0, 2, 2, 1, 0, 1, 2, 1, 0, 2, 2, 1, 2, 0, 0], dtype=int64)

# %%
sklearn_pred = clf.predict(X_test)
my_clf_pred = my_clf.predict(X_test)
assert abs( accuracy_score(y_test, my_clf_pred) -  accuracy_score(y_test, sklearn_pred ) )<0.005, "Score must be simillar"

# %% [markdown]
# **Задание 4 (2.5 балла)**
#
# Рассмотрим новый датасет 20 newsgroups

# %%
newsgroups = fetch_20newsgroups(subset='train',remove=['headers','footers', 'quotes'])

# %%
data = newsgroups['data']
target = newsgroups['target']

# %%
import re

data = [re.sub('[\W]', ' ', data[i]) for i in range(len(data))]
data = [re.sub(' [a-z]{1,3} ', ' ', data[i].lower()) for i in range(len(data))]

d = []
y = []

for i in range(len(data)):
    if len(data[i].split()):
        d.append(data[i])
        y.append(target[i])
data
# Out:
# ['i wondering anyone there could enlighten this saw other  2 door sports  looked from late 60s  early 70s  called bricklin  doors were really small  addition  front bumper separate from rest body  this  know  anyone tellme model name  engine specs  years production  where this made  history  whatever info have this funky looking  please mail ',
#  'a fair number brave souls upgraded their clock oscillator have shared their experiences this poll  please send brief message detailing your experiences with procedure  speed attained  rated speed  cards adapters  heat sinks  hour usage day  floppy disk functionality with 800 1 4 floppies especially requested   will summarizing next days  please the network knowledge base have done clock upgrade haven answered this poll  thanks ',
#  'well folks  plus finally gave ghost this weekend after starting life 512k back 1985   sooo  the market new machine sooner than intended     looking into picking powerbook 160 maybe 180 have bunch questions that  hopefully  somebody answer     does anybody know dirt when next round powerbook introductions expected   heard 185c supposed make appearence  this summer  haven heard anymore   since have access macleak  wondering anybody there more info       anybody heard rumors about price drops powerbook line like ones duo just went through recently     what impression display 180   could probably swing 180 got 80mb disk rather than 120  don really have feel how much  better  display   looks great store  that   really that good     could solicit some opinions people use 160 180 day its worth taking disk size money get active display    realize this real subjective question  ve only played around with machines computer store breifly figured opinions somebody actually uses machine daily might prove helpful      well does hellcats perform       thanks bunch advance any info   could email  post summary  news reading time premium with finals just around corner            willis     twillis purdue         purdue electrical engineering',
#  ' have weitek address phone number   like some information about this chip  ',
#  'from article  c5owcb n3p world com   tombaker world com  baker     understanding that  expected errors  basically known bugs warning system software   things checked that have right values because they aren till after launch  suchlike  rather than the code possibly introduce bugs  they just tell crew   see warning  213 before liftoff  ignore  ',
#  '     course   term must rigidly defined bill    doubt uses this term that   are using quote allegedly from  you back      read article presenting first argument about weapons mass destruction  commonly understood  then switching other topics  first point evidently show that all weapons should allowed  then later analysis  given this understanding  consider another class     ',
#  'there were people responded request info treatment astrocytomas through email  whom couldn thank directly because mail bouncing probs  sean  debra  sharon    thought publicly thank everyone   thanks     sure glad accidentally   instead   when trying delete file last september   hmmm     news   what this       ',
#  '                                                                       this shows that don know much about scsi   scsi 1  with scsi 1 controler chip  range indeed 0 5mb that you have right about scsi scsi 1  with scsi 2 controller chip   4 6mb with 10mb burst  8   note increase speed  mac quadra uses this version scsi 1  does exist  some this too  scsi 2  8 scsi 1 mode            4 6mb with 10mb burst scsi 2  16 wide fast mode    8 12mb with 20mb burst scsi 2  32 wide fast       15 20mb with 40mb burst   your data  although scsi twice fast esdi  correct with scsi 2 controller chip scsi 1 reach 10mb which indeed  20  faster than   120  8 3 9 96   these scsi facts have been posted this newsgroup mac   info sheet  available  sumex stanford  36 44 0 6  info report  ibm compare version     should 173 161 still there    part this problem both and are inconsiant about what scsi which   though well documented that quadra scsi 2 chip apple salesperson said  uses fast scsi 1 chip   a 6mb  10mb burst does  scsi 1 5mb maximum synchronous quadra uses ansynchronous scsi which slower   seems that and see scsi 1 interface think  scsi 1  when maybe scsi 1 interface driven machine scsi 2 controller chip 8 mode  which much faster then true scsi 1  ',
#  'i have 3 0 downloaded several icons bmp can figure how change  wallpaper  the icons   help would appreciated    thanx    brando',
#  '   had board over year  does work with diskdoubler  not with autodoubler  a licensing problem with stac technologies  owners board compression technology   writing this from memory  lost reference  please correct m wrong    using board  had problems with file icons being lost  s hard whether the board fault something else  however  decompress troubled file recompress without board  icon usually reappears  because above mentioned licensing problem  freeware expansion utility expand will decompress board compressed file unless have board installed   since stac its product  seems unlikely that holes autodoubler diskdoubler related board will fixed  which  makes very reluctant stac product since they being stinky   hey  that competition      ',
#  'i have line ducati 900gts 1978 model with 17k clock   runs very well  paint bronze brown orange faded  leaks oil pops 1st with hard accel   shop will trans oil  leak   they sold bike 1 only owner   they want  3495  am thinking more like  3k   opinions there   please email  thanks   would nice stable mate beemer   then get bike call myself axis motors                                                                                tuba   irwin        honk therefore      computrac richardson irwin cmptrc lonestar     0826           r75 6 ',
#  '  that pretty much  not but understand that this jewish thinking  however  jews believe that covenant between yhwh the patriarchs  abraham moses  this case  establishes moral code follow mankind  even jews could decide where boundaries fall  though   understand  sadducees believed that torah all that required  whereas pharisees  ancestors modern judaism  believed that torah available interpretation lead understanding required morality its nuances    talmud    essence this that biblical morality interface between and yhwh  jew christian  does necessarily indicate anything about yhwh outside that relationship  although can speculate     trouble with this that really know what  created image  means  heard number different opinions this have still come conclusion  this rather upsets apple cart wants base life script this shaky foundation  metaphors unashamedly   living christ example  know very little about jesus person  only have recorded utterances set narratives followers  some very small references from comtemporary historians  revelation aside  can only  know  christ second hand worse   this attempt debunk christianity  although seem that initially   point trying make that only really have bible interpret  that interpretation humanity  guess this where faith relevation comes with its inherent subjectiveness     there an absolute moral code  there undoubtably multiple moral codes  multiple moral codes founded absolute moral code  example  parent tell child never swear  the child assume that parent never swears simply because parent told child that  wrong    parent swear like trooper pub  where there children    wrongness  here the child disobeys parent  parent feel that  inappropriate  swear front children may quite happy swear front animals  analogy does quite hold water because child knows that the same type parent  may parent later life  you the gist  incidentally  young child considers directive absolute until gets older  piaget  learns morality own   david       religion ',
#  '   ',
#  '     description  external tank  option ssf redesign deleted     keep things  both  external tank   wingless orbiter  options have been deleted from ssf redesign options list  today  4 23  edition new york times reports that connor told panel that some redesign proposals have been dropped  such using  giant external fuel tanks used launching space shuttles   building  station around existing space shuttle with wings tail removed    currently  there three options being considered  presented advisory panel meeting yesterday  reported today times    option     cost modular approach this option being studied team from msfc   aside  there ssf redesign teams msfc   larc supporting srt  station redesign team  crystal city  both lerc reston folks also site these locations  helping respective teams with their redesign activities   features this option       uses  1   modular developed lockheed that      qualified sts elv  bus provides propulsion       communications    data management  lockheed developed this      the force        power station capability  obtained 3 shuttle flights       solar arrays used provide 20 power  vehicle      flies  arrow mode  optimize microgravity environment       shuttle spacelab missions would utilize vehilce power      source 30 missions       human tended capability  opposed old sexist term      tended capability  achieved addition      common module  this modified version existing      lab module  docking ports added the international      partners  labs  taking place nodes        shuttle docked station 60 missions       orbiter would provide crew habitability   capability       international human tended  the nasda   modules       another 20 power      permanent human presence capability  3rd power module       s  habitation module  acrv  assured crew return      vehicle    option     space station freedom derived option   team based larc  lead mike griffin  this option looks alot like existing design  which have come know love     this option assumes lightweight external tank available use ssf assembly flights  does option     also   number flights computed 51 6 inclination orbit  both options       build occurs phases       initial research capability reached after 3 flights  power      transferred from vehicle orbiter spacelab  when      visits       tended capability  griffin not adopted sexist      language  achieved after 8 flights  s       deployed  1 solar power module provides 20 power       permanent human presence capability occurs after 10 flights       keeping orbiter orbit an acrv  sometimes      there would orbiters orbit   acrv  the      second that comes logistics   supply         fault tolerance capability  achieved after 14 flights       with addition 2nd power module  another thermal      control system radiator  more propulsion modules       after 20 flights  internationals board  more power       habitation module  acrv added finish      assembly 24 flights   most systems currently are used this option   with exception data management system  which major changes ',
  92 escort         james   james  callison    microcomputer coordinator  oklahoma center callison uokmax uoknor         callison aardvark uoknor disclaimer  not engineer  play work      forecast calls thunder    89 bird     hell thing  killing  take away has  all ever gonna have        will munny   unforgiven                                                                           61   beyond  under 25  group  have experience years that might interesting   owned 1985 toyota celica   decided myself gift   more exotic   front runners included toyota supra turbo the porsche 924  1987 model years   narrowed down those   liked simplicity handling  snob appeal   driving porsche   supra turbo less money had more features performance   almost personal luxury   better acceleration higher speed than 924  almost ready give buying impulse the 924  decided stop insurance agent office way   asked about what would happen rate with either     buy supra  your rate classification will same celica   85 celica considered subcompact for that year rated the safest cars   with slight increase because car will 2 years newer   lower risk division will continue handle your account     buy porsche 924  have change the standard  higher  rate company your rate will double   you with 944  another story again   cover rest this year  cancel after that      the supra much faster than 924  the 924 actually faster than  standard  944   that doens make sense      that what book says   insure corvettes  either   some reason  underwriters consider supras   their drivers   very traditional conservative     eventually went with supra number reasons   porsche dealer nice salesman interested  tough high pressure the back room   equal monthly payments  would have taken year longer for porsche  plus higher insurance   concluded that high insurance related probability auto theft                                            ev ...
#  'i would like able amplify voltage signal which output from thermocouple  preferably factor 100 1000      that resulting voltage fed more easily into personal computer based data acquisition card   might anyone able point references such circuits   have seen simple amplifier circuits before  am sure well they work practice   this case  like something which will amplify sufficiently  nicely  used thermocouples   degrees accuracy better  ',
#  'question    what exact entry  parameter syntax please   terminal configuration file  loaded when terminal boots   another system  tcp access control list        background    have unix systems  1  3b2 running x11r3 mit x11r4  2  ss10 without      want have window sun the 3b2 ncd terminal same time   this manually the network parameter access control list  then login telnet session  great      tried  xhost  work failed   either syntax wrong x11r3 implementation bogus      trying edit ncd configuration file that loaded when  boots   matter what entry edit  ncd still boots with tcp access control list containing only 3b2    manuals worthless help would most appreciated    thanks ',
#  '        these seem like  little things    least  they orders worse than motto   think that motto  little thing  that will lead worse things ',
#  ' think that mike foligno the captain sabres when traded leafs  also  wasn rick vaive captain leafs when traded chicago  with steve thomas olcyzk someone   speaking leafs  believe that darryl sittler their captain  torn   his jersey think claimed captaincy later  when traded flyers   yeah  course  gretzky the captain oilers before traded wasn  ',
#  '        catalog personal computing tools engineers scien        tists  lists hardware cards application software packages        ps 2 class machines   focus engineering scien        tific applications  such data acquisition control         design automation  data analysis presentation           would like free copy  reply with your    postal         mailing address   have copy this catalog front i write this  does have tons qool stuff   impression that they not send  browsers   appears that your buyer engineer they want waste catalog  when get catalog there  code  have give them  ensure your continued subscription    anyway  want touch with them  company  personal computing tools 550 division street campbell  95008  408  378 8400   they also have   toll free   ordering tech support ',
#  '    control the window itself  upper left corner window  single click  being simplistic   font option  8 12 about biggest can without characters turning funky  ',
#  'i know about specific problem mentioned your message  definitely scsi problems between q700 venerable jasmine megadrive 10 cartridge drives   solution get silverlining   none loops that involved blind writes worked drives  fact only loop that worked the  macintosh software  loop  whatever that means  ',
#  'hello       looking voice input capability user interface developing hp730  unix  workstation   would greatly appreciate  information anyone would care offer about voice input systems that  easily accessible from unix environment         names adresses applicable vendors  well  experiences have with specific systems  would very helpful        please respond email  will post summary there  sufficient interest    thanks      have found several impressive systems ibm  would  like avoid hassle purchasing maintaining separate  possible                                                                                   hinckley  kph2q virginia  university virginia  neurosurgical visualization laboratory',
#  'pat   yeah  windscreen down most   canopies ended completely   course  environment space continues suck       tommy                                                                           mcwilliams 517 355 2178      radius vision increases  18084tm msu 336 9591    circumference mystery grows ',
#  'i trying write image display program that uses mit shared memory extension   shared memory segment gets allocated attached process with problem  the program crashes first call xshmputimage  with following message   error failed request   badshmseg  invalid shared segment parameter    major opcode failed request   133  shm    minor opcode failed request   3  x_shmputimage    segment failed request 0x0   serial number failed request   741   current serial number output stream   742  like said  error checking the calls shmget shmat that necessary create shared memory segment  well checking xshmattach   there problems   anybody had same problem used shm without having same problem  please know   way  running openwindows 3 0 sun sparc2 ',
#  'i have been following this thread talk religion  religion christian bible study here with interest   amazed different biblical argument those oppose sabbath present    question comes mind  especially since last was answered from scripture   maybe may wish provide first response   there lot talk about sabbath being ceremonial   answer this   since commandments law with parts what biblical basis have decided that only sabbath portion ceremonial  say that seventh the sabbath not applicable gentile christians   does that mean sabbath commandment been annulled   references please   did intend requirements jews applicable gentile christians did make plain that gentiles were grafted into commonwealth israel   darius',
#  'hi     anyone tell where get copy updated canon 200 printer driver windows 3 1    have 1 0 which comes with 200 printer  just wonder there newer version ',
#  ' herman  would think all people would could distinguish between  health   treatment disease   the prevention medicine people preach this the time  cannot health  can treatment disease  assuming are lucky enough have disease which treated  rich person with terminal disease bit luck  there such thing  adequately covered  there never will    for what worth  the first admit that patients ',
#  '  that zoologists refer a  fecal shield   colonel semen   budienny  subsequent soviet military fame  said about  armenian genocide 2 5 million defenseless turkish kurdish  women  children elderly people during visit anatolia  june 1919 that   armenians become troublemakers  their hinchakist  dashnakist parties were opportunist  serving lackeys  whatever power happened ascendent    september 16  1920  major general  thwaites  director military intelligence  wrote lord hardinge  under secretary state foreign affairs       useless pretend that armenians satisfactory  allies  deserving the sympathy which they claim   1    1   331 3411 158288   special collection stanford hoover library  donated georgia cutler  letter dated  1  1943 states that   prescot hall wrote large volume prove that armenians were  and never could desirable citizens  that they would   always unscrupulous merchants     source  documents  volume  1919            document  50   archive  4 3621  cabin  162  drawer           5  file  2905  section  433  contents  6  6 1  6 2           36th division command   militia commander ismail hakki    eight days  armenians have been forcibly obstructing people from  leaving their homes going from village other  and night  they rounding male inhabitants  taking them unknown destinations   after which nothing further heard them   informed from statements  those succeeded escaping wounded from massacres around  taskilise ruins   women children being openly murdered  being gathered church square similar places  most inhuman  barbarous acts have been committed against moslems eight days              document  52   archive  4 3671  cabin  163  drawer           1  file  2907  section  440  contents  6 6  6 7            1st caucasian army corps command  2nd caucasian army corps         command  communications zone inspectorate   commander 3rd army         general    almost russian units opposite front have been withdrawn   population loyal regions behind russian positions  facing ever increasing threat suppression well cruelties  abuses armenians have decided systematically annihilate  moslem population regions under their occupation  have   regularly informed russian command these atrocities  cruelties have gained impression that above authority  seems failing restoring order     serdar argic',
#  'i sent response white house   0005895485 mcimail  white house   received nice  automatic reply from micmail noting  passing  that had included snail address  would reply course   those care  reply    1   protect voice network   2  privately developed crypto always been available   always will    think about do   enforcement given that fact about hope   legislate against   3  needs crypto system designer not the   clipper chip   want freely export uses algorithms    like    which already freely available   destination country ',
#  'an excellent automatic found subaru legacy   switches  sport  mode when electronics figure   when driver sets switch   which proper do    what does  sport  mode entail   several things   1  revving line  the limiter case legacy   2  delayed upshifts     lift briefly  will remain  gear   this handy are charging through corners  would like without distraction upshifts when there  another curve approaching   3  part throttle downshifts  based  speed  which pedal  depressed  rather than  position  pedal   modern  electronics measure this very easily switch sport mode   this wonderful want charge through green light about  turn   audi senses this very well can downshift  little half throttle right foot fast enough   also  think that smart automatic deliver better mileage than dumb driver with stick  else being equal   remember that idea stick being more economical than automatic makes assumption that driver smart enough know what gear for each situation   many times have ridden with inattentive driver cruising highway 55 65 4th gear  5 speed      many   people drive manuals  really  know what best gear for every conceivable situation   sure there will some know  suspect that chip controlled automatic with possible scenario ratio combinations stored likely better   also that previous assumptions were proved wrong after car with instantaneous readout    high gear  revs wide open throttle more economical than gear  high revs small throttle opening   explanation quite simple sits down think about  not that obvious first sight  ',
#  '     squid   keep tradition alive    kinda like fish games     ',
#  'sorry  tell exactly what need   need utility automatic updating  deleting  adding  changing    files windows   program should from batchfile program script under windows   will the utility updating win  other files  meny     find any host ',
#  'archive name  space new_probes last modified   date  93 04 01 14 39 17    upcoming planetary probes   missions schedules      information upcoming currently active missions mentioned below     would welcome  sources  nasa fact sheets  cassini mission design     team  isas nasda launch schedules  press kits        asuka  astro    isas  japan  astronomy satellite  launched into     earth orbit 2 20 93  equipped with large area wide wavelength  1 20     angstrom  telescope  ccd cameras  imaging     scintillation proportional counters        cassini   saturn orbiter titan atmosphere probe  cassini joint     nasa project designed accomplish exploration saturnian     system with cassini saturn orbiter huygens titan probe  cassini     scheduled launch aboard titan centaur october 1997      after gravity assists venus  earth jupiter vvejga     trajectory  spacecraft will arrive saturn june 2004  upon     arrival  cassini spacecraft performs several maneuvers achieve     orbit around saturn  near end this initial orbit  huygens     probe separates from orbiter descends through atmosphere     titan  orbiter relays probe data earth about 3 hours     while probe enters traverses cloudy atmosphere     surface  after completion probe mission  orbiter     continues touring saturnian system three half years  titan     synchronous orbit trajectories will allow about 35 flybys titan     targeted flybys iapetus  dione enceladus  objectives     mission threefold  conduct detailed studies saturn atmosphere      rings magnetosphere  conduct close studies saturn     satellites  characterize titan atmosphere surface       the most intriguing aspects titan possibility that     surface covered part with lakes liquid hydrocarbons that     result from photochemical processes upper atmosphere  these     hydrocarbons condense form global smog layer eventually rain     down onto surface  cassini orbiter will onboard radar     peer through titan clouds determine there liquid     surface  experiments aboard both orbiter the entry probe will     investigate chemical processes that produce this unique atmosphere       cassini mission named jean dominique cassini  1625 1712       first director paris observatory  discovered several     saturn satellites the major division rings  titan     atmospheric entry probe named the dutch physicist christiaan     huygens  1629 1695   discovered titan first described true     nature saturn rings     scheduled dates the cassini mission  vvejga trajectory                                                                      10 06 97   titan centaur launch     04 21 98   venus 1 gravity assist     06 20 99   venus 2 gravity assist     08 16 99   earth gravity assist     12 30 00   jupiter gravity assist     06 25 04   saturn arrival     01 09 05   titan probe release     01 30 05   titan probe entry     06 25 08   primary mission       schedule last updated 7 22 92        galileo   jupiter orbiter atmosphere probe  transit  returned     first resolved images asteroid  gaspra  while transit     jupiter  efforts unfurl stuck high gain antenna   have     essentially been abandoned  has developed backup plan using data     compression  jpeg like images  lossless compression data from     other instruments  which should allow mission achieve     approximately 70  original objectives       galileo schedule                          10 18 89   launch from space shuttle     02 09 90   venus flyby     10    90   venus data playback     12 08 90   1st earth flyby     05 01 91   high gain antenna unfurled     07 91   06 92   1st asteroid belt passage     10 29 91   asteroid gaspra flyby     12 08 92   2nd earth flyby     05 93   11 93   2nd asteroid belt passage     08 28 93   asteroid flyby     07 02 95   probe separation     07 09 95   orbiter deflection maneuver     12 95   10 97   orbital tour jovian moons     12 07 95   jupiter encounter     07 18 96   ganymede     09 28 96   ganymede     12 12 96   callisto     01 23 97   europa    ...
#  'hello netters    does anyone there know ftp sites projects  plans  an electrical nature      jason',
# ...
#  '  perhaps ought have supported known genocidist   provided with weapon systems  tactical support  technology     made suddam hussein    what bush call   ally freind               cheat hillary  ',
#  ' think this weak argument   fact  there   references jesus _antiquities jews_  which unquestionably least been altered christians   origen wrote  third century  that josephus not recognize jesus messiah  while long passage says opposite   there arabic manuscript _antiquities jews_ which contains version passage which much less gung jesus may authentic     there question that origen  third century  reference jesus josephus   there manuscripts _antiquities_ which lack references   possible that fabricated whole cloth inserted  don think very likely  i think there consensus scholarly community that this case   know  wells takes this position  that because takes very small minority view that jesus never existed   is professor german  biblical history testament anything directly relevant historicity jesus  ',
#  'mr decenso  spite requiring scholarly opinion hanging judas  rejects that scholarly opinion those scholars then rephrases those scholars opinion subject       actually  further research the greek word  apacgw   will find that does denote success   those scholars indeed have excellent reason assume that suicide successful   pointed  recently checked several lexicons     greek english lexicon new testament   louw nida   robinson greek english lexicon new testament    greek english lexicon new testament   grimm   word study concordance   tynsdale   greek english lexicon new testament other    early christian writings   bauer arndt gingrich   new analytical greek lexicon   perschbacher  couple simply stated  hanged oneself   couple were more explicit  stated that  apacgw  means specifically  kill yourself hanging   couple also noted that meaning the root words  apacgw   strangle  throttle choke   which pretty much invalidates guy suggested david joslin that judas hung upside down    the best references though   robinson greek english lexicon new testament   only stated translation  gave both root words  literal translation  related greek words which the same roots  also other presented specific examples word greek literature  give further context      word  apagchw  two root words   gchw   strangle  root  the root word   means literally  away   this root words included words which denote transition   mean transition place   greek word  apagello  means send message      also denote change state specifically change from life death   robinson specifically makes comparison word  apokteiuo   which means  kill   literal meaning word  apacgw  means  throttle  strangle out way   implicitly denotes change life state   away from life  death    while word  apacgw  does mean  hang   specifically denotes death well   thus robinson quite specific when state that means  hang oneself  one life hanging   then notes the  apacgw  homers odessy 19 230 denote context   presents that example  apacgw  being used explicitly mean  suicide hanging   since there perfectly good word strangling  without added denotation  death   you insist that bible written  every word precicely correct  are stuck with complete meaning  apacgw    since word  apacgw  used  then death denoted result     way  note that decenso also presents example  apacgw     note decenso  say  septuagint translation from hebrew greek  you have shown original meaning hebrew   the hebrew  died    thus whether simply echoed greek   should also pointed that  regardless added  died   correct translation would still  apacgw   man indeed from strangulation  redundant  correct    further  have evidence that septuagint repeatedly rewritten reedited  which included versions which contradicted each other   such editing not even necessarily executed greeks   thus not sure that can the septuagint now stands  paragon ancient greek    what really need prove your point decenso  example  ancient greek  someone committing  apacgw  surviving   otherwise would you simply making worthless assertions without corresponding evidence    would note decenso  that everytime out way research your apparently contrived exegisis  pretty much find false   thus  think that are going the text  something over above what source clearly says  then had better have explicit greek historical source justify    way  rose statement about trees around potter field    unless rose show that these trees two thousand years  that there 2000 year stumps there  2 thousand year description area which mentions such trees  then inappropriate him assert that present placement trees prove location trees thousand years  after  things change     to your other argument   that money judas used the same 30 silvers    true  peter  author acts  does specifically call judas  betrayal  iniquity   for that matter  neither does john specifically call judas  actions  iniquity  either   further john 13 29 not that judas took       some thought that because  j ...
#  'what address interliving  memmory modules  interliving  thanks advance the info  robert   ',
#  'pens 6 devils 6  first period  scoring  1  pittsburgh  daniels needham  tippett 4 14  2  devils   lemieux semak  driver 10 19   3  pittsburgh  stevens  tocchet  murphy 12 40ppg   4  devils  zelepukin driver  niedermayer  17 26   penalties   stevens roughing 1 30    pellerin double minor cross checking 1 30    zelepukin tripping 7 21    stasny holding 11 15    taglianetti roughing 13 51    lemieux  roughing 13 51    jagr tripping 15 23   second period  scoring  5  pittsburgh  lemieux murphy  tocchet 1 42  6  devils  semak lemieux  zelepukin 2 27   7  pittsburgh  mceachern  jagr  barrasso 4 24   8   stevens guerin  pellerin 5 45   9  pittsburgh  lemieux unassisted 12 40shg   10  devils  richer  nicholls 15 53   11  devils  lemieux zelepukin 17 40   penalties   stevens roughing 3 06    mckay roughing 3 06    mullen  hooking 10 42    tocchet roughing 12 06    stevens slashing  12 06    lemieux unsportsmanlike conduct 12 40     samuelsson cross checking 20 00    barrasso double minor spearing  served mceachern  20 00    holik cross checking 20 00    lemieux roughing 20 00   third period  scoring  12  pittsburgh  mullen jagr  lemieux 18 54  penalties   daneyko interference 3 37    stevens roughing  9 18    holik roughing 9 18    match penalty game misconduct 9 50   zelepukin tripping 12 01    stevens roughing 18 41    daneyko roughing 18 41   overtime  scoring  scoring   penalties  penalties   shots goal  pittsburgh  9 11 8 2 30 devils  12 15 9 3 39  goalies  barrasso 39 shots  33 saves  43 14 5  billington 30 shots  24 saves    devorski  linesmen  gauthier  vines',
#  ' think just wanted henneman some work  because  tigers days both day before the after ',
#  'last heard because budget such air farce only  space command  left   rest missions were generally given air farce    probably good reason to transfer from army guard air guard    hate walking with pack back  how put your application job kitchen worker  that have done kp  kitchen police   ',
#  '                                                                                           sounds pretty lame   see understand  your  friends  charge extra  just much usually have for little friendliness  seems like being  serviced  some  friendly  sales people   ',
#  '      must have tried very hard  just opend mine about 2 seconds  take look bottom  dial that turns open much like older mouses used have  bit harder turn first is quite simple open        well  don match pins correctly will have some problems  close look socket should give idea proper orientation chip ',
#  '   hmmmm  not sure this true   according mike lang good stagie  along with rest crews pittsburgh  they  winning streak could have stopped because regular season mark  would think this would also hold with unbeaten streak regular season games ',
#  'some weeks  someone posted article telling when where hamfest computerfest going help dayton   unfortunately  lost article was wondering someone could repost   believe being held 23 24 25 this month dayton convention center m sure   help more details would greatly appreciated ',
#  ' called      balloons were sufficiently orbit that they experienced some resistance   when they were finally punctured  this  preasure  the internal preasure that needed maintain spherical shape against this resistance  caused them catastrophically deflated   large silvered shards that remained were easily visible some time before reentry  though longer useful passive transponder ',
#  'it the   have gak ',
#  'i have vt200 vt100 compatible terminal with 1200 external hyess modem amber screens 101 keyboard cable make offer 0 ',
#  ' obviously  really know   they  have  spoken  of state christopher recent trip   they have provided millions  they have participated airlifts sarajevo   they  would  supply military  would lift embargo  arms sales     above    kuwait directly participated airlift food sarajevo       some might kuwaitis non white  ooops  forgot  kuwaitis  rich    loaded with petro dollars   they count ',
#  '    have noticed this exact same phenomenon occurs with lciii   perhaps quirk new machines ',
#  ' essential tremor progressive hereditary tremor that gets worse when patient tries the effected member   limbs  vocal cords  head involved   inderal beta blocker usually effective diminishing tremor   alcohol mysoline also effective  alcohol toxic a treatment                                                                                   gordon banks  n3jxp         skepticism chastity intellect  geb cadre pitt      shameful surrender soon   ',
#  'sorry posting this  e mail keeps bouncing   maybe will help others here  anyway  therefore pray others will read this   actually response from aunt  has 5 kids  since have none        posting this good christian relative does have mail access   since this aunt uncle have 5 kids felt they would more relevant than  have none          13 year  13yo  twins  10yo  6 5yo  2yo girl       call spanking  they   very rarely        call spanking because more reaction something very dangerous  such trying stick their finger fan running into road   maybe 3 4 times each except the 2yo girl  has been spanked       they call that because  does  hurt their feelings  course give the hugs stuff ensure they know they still loved         that would painful   too traumatic they never recall they were punished   besides  must immediate  taking time get toolmeans not doing right away  that lessens impact   very emotional child   which evidenced fact that little slap rear   which hurts perhaps 5 seconds   called spanking       lots logical consequences   instance  when 4yo matthew dared good friend jump his treehouse would push out  made sure they didn play together 5 days know that would make lose friends very quickly   never done anything like that since       also time their rooms   timer they keep arguing with over leaving  since hard argue with macine  will the closed door tell them timeout be over until they calm down they tantrumy   the the stairs when they really young        40       bath  ohio   right outside akron  northeast part ohio         none kids would dream   hope can this teach parents that physical punishment always required   parents that excuse too hard        lots timeouts  same use   family husband have never used spankings   fact  grandmother was 11 kids  they were almost never spanked   this around turn century    none has ever been afoul law   made law       jesus says  referring small child whom holding  that  what the least these  also    bible also says things kind  merciful  especially loving   colossians 3 12 15   there room selfish anger  which admit been tempted with times   when felt like spanking hard anger  maybe kid deserved little slap rear  what would have given would have been devil work   could feel temptation  just angrily ordered kid her room went room myself   after praying asking forgiveness  much calmer  did feel like spanking  felt that what done enough punishment ',
#  ...]

# %% [markdown]
# Преобразуйте текстовые данные из data с помощью [CountVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html). Словарь можно ограничить по частотности.

# %%
vectorizer = sklearn.feature_extraction.text.CountVectorizer(max_df=0.8, stop_words='english')

x = vectorizer.fit_transform(d)
y = np.asarray(y)

# %%
x.shape
# Out:
# (11002, 97090)

# %% [markdown]
# *Так мы получили векторное представление наших текстов. Значит можно приступать к задаче обучения модели*

# %% [markdown]
# Реализуйте разбиение выборки для кросс-валидации на 3 фолдах. Разрешено использовать sklearn.cross_validation

# %%
clf = MyKNeighborsClassifier(3)
clf.fit(x, y)

# %%
scores = np.zeros(15)

for i in range(15):
    scores = np.mean(cross_val_score(MyKNeighborsClassifier(i + 1), x, y, cv=10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\program files\python37\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      60     try:
# ---> 61         return bound(*args, **kwds)
#      62     except TypeError:
#
# TypeError: Partition index must be integer
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-265-6467e3f0e8dc> in <module>
#       2
#       3 for i in range(15):
# ----> 4     scores = np.mean(cross_val_score(MyKNeighborsClassifier(i + 1), x, y, cv=10))
#
# c:\program files\python37\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     388                                 fit_params=fit_params,
#     389                                 pre_dispatch=pre_dispatch,
# --> 390                                 error_score=error_score)
#     391     return cv_results['test_score']
#     392
#
# c:\program files\python37\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     234             return_times=True, return_estimator=return_estimator,
#     235             error_score=error_score)
# --> 236         for train, test in cv.split(X, y, groups))
#     237
#     238     zipped_scores = list(zip(*scores))
#
# c:\program files\python37\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# c:\program files\python37\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# c:\program files\python37\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# c:\program files\python37\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# c:\program files\python37\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# c:\program files\python37\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# c:\program files\python37\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# c:\program files\python37\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     542     else:
#     543         fit_time = time.time() - start_time
# --> 544         test_scores = _score(estimator, X_test, y_test, scorer)
#     545         score_time = time.time() - start_time - fit_time
#     546         if return_train_score:
#
# c:\program files\python37\lib\site-packages\sklearn\model_selection\_validation.py in _score(estimator, X_test, y_test, scorer)
#     589         scores = scorer(estimator, X_test)
#     590     else:
# --> 591         scores = scorer(estimator, X_test, y_test)
#     592
#     593     error_msg = ("scoring must return a number, got %s (%s) "
#
# c:\program files\python37\lib\site-packages\sklearn\metrics\_scorer.py in __call__(self, estimator, *args, **kwargs)
#      87                                       *args, **kwargs)
#      88             else:
# ---> 89                 score = scorer(estimator, *args, **kwargs)
#      90             scores[name] = score
#      91         return scores
#
# c:\program files\python37\lib\site-packages\sklearn\metrics\_scorer.py in _passthrough_scorer(estimator, *args, **kwargs)
#     369 def _passthrough_scorer(estimator, *args, **kwargs):
#     370     """Function that wraps estimator.score"""
# --> 371     return estimator.score(*args, **kwargs)
#     372
#     373
#
# <ipython-input-204-9c3cca9be4df> in score(self, X, y)
#      55             return np.apply_along_axis(self.predict_proba, 1, X)
#      56     def score(self, X, y):
# ---> 57         return accuracy_score(y, self.predict(X))
#      58
#
# <ipython-input-204-9c3cca9be4df> in predict(self, X)
#      52         elif self.algorithm == 'brute':
#      53             if type(X) == scipy.sparse.csr.csr_matrix:
# ---> 54                 return self.brute(X)
#      55             return np.apply_along_axis(self.predict_proba, 1, X)
#      56     def score(self, X, y):
#
# <ipython-input-204-9c3cca9be4df> in brute(self, x)
#      25             dist = pairwise_distances(x, self.dataset, metric=self.metric)
#      26
# ---> 27             indices = np.argpartition(dist, self.k, axis = 1)[:, :self.k]
#      28
#      29             return np.apply_along_axis(np.bincount, 1, self.answers[indices], minlength=self.k).argmax(axis=1)
#
# <__array_function__ internals> in argpartition(*args, **kwargs)
#
# c:\program files\python37\lib\site-packages\numpy\core\fromnumeric.py in argpartition(a, kth, axis, kind, order)
#     817
#     818     """
# --> 819     return _wrapfunc(a, 'argpartition', kth, axis=axis, kind=kind, order=order)
#     820
#     821
#
# c:\program files\python37\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      68         # Call _wrapit from within the except clause to ensure a potential
#      69         # exception has a traceback chain.
# ---> 70         return _wrapit(obj, method, *args, **kwds)
#      71
#      72
#
# c:\program files\python37\lib\site-packages\numpy\core\fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      45     except AttributeError:
#      46         wrap = None
# ---> 47     result = getattr(asarray(obj), method)(*args, **kwds)
#      48     if wrap:
#      49         if not isinstance(result, mu.ndarray):
#
# TypeError: Partition index must be integer

# %% [markdown]
# Напишите метод, позволяющий найти оптимальное количество ближайших соседей(дающее максимальную точность в среднем на валидации на 3 фолдах).
# Постройте график зависимости средней точности от количества соседей. Можно рассмотреть число соседей от 1 до 10.

# %% [markdown]
# Как изменится качество на валидации, если:
#
# 1. Используется косинусная метрика вместо евклидовой.
# 2. К текстам применяется TfIdf векторизацию( sklearn.feature_extraction.text.TfidfVectorizer)
#
# Сравните модели, выберите лучшую.

# %% [markdown]
# Загрузим  теперь test  часть нашей выборки и преобразуем её аналогично с train частью. Не забудьте, что наборы слов в train и test части могут отличаться.

# %%
newsgroups = fetch_20newsgroups(subset='test',remove=['headers','footers', 'quotes'])

# %% [markdown]
# Оценим точность вашей лучшей модели на test части датасета. Отличается ли оно от кросс-валидации? Попробуйте сделать выводы, почему отличается качество.
